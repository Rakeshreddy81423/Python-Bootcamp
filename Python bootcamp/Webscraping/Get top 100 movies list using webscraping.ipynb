# %% [markdown]
# # Scraping the data from  https://stacker.com/stories/1587/100-best-movies-all-time  to get top 100 movies to watch

# %%
from bs4 import BeautifulSoup
import requests

import html

# %%
url="https://stacker.com/stories/1587/100-best-movies-all-time"

response = requests.get(url)

greatest_movies = response.text
soup = BeautifulSoup(greatest_movies,"html.parser")

all_movies = soup.find_all(name="h2",class_="ct-slideshow__slide__text-container__caption")
movie_names =[]

for movie in all_movies:
    movie_names.append(movie.getText().split("\n")[1].strip("#"))
    
top_100_movies = movie_names[1:][::-1]


for movie in top_100_movies:
    print(movie)
# Out:
# 1. The Godfather (1972)
# 2. 12 Angry Men (1957)
# 3. Casablanca (1942)
# 4. Rear Window (1954)
# 5. City Lights (1931)
# 6. Pulp Fiction (1994)
# 7. The Lord of the Rings: The Return of the King (2003)
# 8. Schindler's List (1993)
# 9. Citizen Kane (1941)
# 10. Vertigo (1958)
# 11. Psycho (1960)
# 12. Singin' in the Rain (1952)
# 13. Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)
# 14. North by Northwest (1959)
# 15. Modern Times (1936)
# 16. Sweet Smell of Success (1957)
# 17. The Lord of the Rings: The Fellowship of the Ring (2001)
# 18. The Godfather: Part II (1974)
# 19. The Wizard of Oz (1939)
# 20. All About Eve (1950)
# 21. The Treasure of the Sierra Madre (1948)
# 22. WALL·E (2008)
# 23. Boyhood (2014)
# 24. Some Like It Hot (1959)
# 25. Touch of Evil (1958)
# 26. Notorious (1946)
# 27. The Night of the Hunter (1955)
# 28. Toy Story (1995)
# 29. Apocalypse Now (1979)
# 30. Gone with the Wind (1939)
# 31. Double Indemnity (1944)
# ...
