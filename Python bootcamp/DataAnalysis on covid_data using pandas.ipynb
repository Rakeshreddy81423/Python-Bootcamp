# %%
import pandas as pd

# %% [markdown]
# In this assignment, we're going to analyze an operate on data from a CSV file. Let's begin by downloading the CSV file.

# %%
from urllib.request import urlretrieve

urlretrieve('https://gist.githubusercontent.com/aakashns/28b2e504b3350afd9bdb157893f9725c/raw/994b65665757f4f8887db1c85986a897abb23d84/countries.csv', 
            'countries.csv')
# Out:
# ('countries.csv', <http.client.HTTPMessage at 0x1eec074a700>)

# %% [markdown]
# Let's load the data from the CSV file into a Pandas data frame.

# %%
countries_df = pd.read_csv('countries.csv')

# %%
countries_df
# Out:
#            location continent  population  life_expectancy  \
# 0       Afghanistan      Asia  38928341.0            64.83
# 1           Albania    Europe   2877800.0            78.57
# 2           Algeria    Africa  43851043.0            76.88
# 3           Andorra    Europe     77265.0            83.73
# 4            Angola    Africa  32866268.0            61.15
# ..              ...       ...         ...              ...
# 205         Vietnam      Asia  97338583.0            75.40
# 206  Western Sahara    Africa    597330.0            70.26
# 207           Yemen      Asia  29825968.0            66.12
# 208          Zambia    Africa  18383956.0            63.89
# 209        Zimbabwe    Africa  14862927.0            61.49
#
#      hospital_beds_per_thousand  gdp_per_capita
# 0                          0.50        1803.987
# 1                          2.89       11803.431
# 2                          1.90       13913.839
# 3                           NaN             NaN
# ...

# %% [markdown]
# **How many countries does the dataframe contain?**

# %%
num_countries = countries_df.shape[0]

# %%
print('There are {} countries in the dataset'.format(num_countries))
# Out:
# There are 210 countries in the dataset

# %% [markdown]
# **Retrieve a list of continents from the dataframe?**

# %%
continents = countries_df['continent'].unique()

# %%
continents
# Out:
# array(['Asia', 'Europe', 'Africa', 'North America', 'South America',
#        'Oceania'], dtype=object)

# %% [markdown]
#  **What is the total population of all the countries listed in this dataset?**

# %%
total_population = countries_df['population'].sum()

# %%
print('The total population is {}.'.format(int(total_population)))
# Out:
# The total population is 7757980095.

# %% [markdown]
# **Create a dataframe containing 10 countries with the highest population.**

# %%
most_populous_df = countries_df.sort_values('population',ascending=False)

# %%
countries_df
# Out:
#            location continent  population  life_expectancy  \
# 0       Afghanistan      Asia  38928341.0            64.83
# 1           Albania    Europe   2877800.0            78.57
# 2           Algeria    Africa  43851043.0            76.88
# 3           Andorra    Europe     77265.0            83.73
# 4            Angola    Africa  32866268.0            61.15
# ..              ...       ...         ...              ...
# 205         Vietnam      Asia  97338583.0            75.40
# 206  Western Sahara    Africa    597330.0            70.26
# 207           Yemen      Asia  29825968.0            66.12
# 208          Zambia    Africa  18383956.0            63.89
# 209        Zimbabwe    Africa  14862927.0            61.49
#
#      hospital_beds_per_thousand  gdp_per_capita
# 0                          0.50        1803.987
# 1                          2.89       11803.431
# 2                          1.90       13913.839
# 3                           NaN             NaN
# ...

# %%
most_populous_df.head(10)
# Out:
#           location      continent    population  life_expectancy  \
# 41           China           Asia  1.439324e+09            76.91
# 90           India           Asia  1.380004e+09            69.66
# 199  United States  North America  3.310026e+08            78.86
# 91       Indonesia           Asia  2.735236e+08            71.72
# 145       Pakistan           Asia  2.208923e+08            67.27
# 27          Brazil  South America  2.125594e+08            75.88
# 141        Nigeria         Africa  2.061396e+08            54.69
# 15      Bangladesh           Asia  1.646894e+08            72.59
# 157         Russia         Europe  1.459345e+08            72.58
# 125         Mexico  North America  1.289328e+08            75.05
#
#      hospital_beds_per_thousand  gdp_per_capita
# 41                         4.34       15308.712
# 90                         0.53        6426.674
# 199                        2.77       54225.446
# 91                         1.04       11188.744
# ...

# %% [markdown]
# **Add a new column in `countries_df` to record the overall GDP per country (product of population & per capita GDP).**

# %%
countries_df['gdp'] = countries_df['population'] * countries_df['gdp_per_capita']

# %%
countries_df
# Out:
#            location continent  population  life_expectancy  \
# 0       Afghanistan      Asia  38928341.0            64.83
# 1           Albania    Europe   2877800.0            78.57
# 2           Algeria    Africa  43851043.0            76.88
# 3           Andorra    Europe     77265.0            83.73
# 4            Angola    Africa  32866268.0            61.15
# ..              ...       ...         ...              ...
# 205         Vietnam      Asia  97338583.0            75.40
# 206  Western Sahara    Africa    597330.0            70.26
# 207           Yemen      Asia  29825968.0            66.12
# 208          Zambia    Africa  18383956.0            63.89
# 209        Zimbabwe    Africa  14862927.0            61.49
#
#      hospital_beds_per_thousand  gdp_per_capita           gdp
# 0                          0.50        1803.987  7.022622e+10
# 1                          2.89       11803.431  3.396791e+10
# 2                          1.90       13913.839  6.101364e+11
# ...

# %% [markdown]
# **Create a dataframe containing 10 countries with the lowest GDP per capita, among the counties with population greater than 100 million.**

# %%
countries_with_greater100m = countries_df['population']>10000000

# %%
countries_with_low_gdp_per_capita = countries_df[countries_with_greater100m].sort_values('gdp_per_capita').head(10)

# %%
countries_with_low_gdp_per_capita
# Out:
#                          location      continent  population  life_expectancy  \
# 32                        Burundi         Africa  11890781.0            61.58
# 52   Democratic Republic of Congo         Africa  89561404.0            60.68
# 140                         Niger         Africa  24206636.0            62.42
# 118                        Malawi         Africa  19129955.0            64.26
# 132                    Mozambique         Africa  31255435.0            60.85
# 117                    Madagascar         Africa  27691019.0            67.04
# 207                         Yemen           Asia  29825968.0            66.12
# 176                   South Sudan         Africa  11193729.0            57.85
# 85                          Haiti  North America  11402533.0            64.00
# 195                        Uganda         Africa  45741000.0            63.37
#
#      hospital_beds_per_thousand  gdp_per_capita           gdp
# ...

# %% [markdown]
# **Create a data frame that counts the number countries in each continent?**

# %%
country_counts_df = countries_df.groupby('continent')['location'].count()

# %%
country_counts_df
# Out:
# continent
# Africa           55
# Asia             47
# Europe           51
# North America    36
# Oceania           8
# South America    13
# Name: location, dtype: int64

# %% [markdown]
# **Create a data frame showing the total population of each continent.**

# %%
continent_populations_df = countries_df.groupby('continent')['population'].sum()

# %%
continent_populations_df
# Out:
# continent
# Africa           1.339424e+09
# Asia             4.607388e+09
# Europe           7.485062e+08
# North America    5.912425e+08
# Oceania          4.095832e+07
# South America    4.304611e+08
# Name: population, dtype: float64

# %% [markdown]
# **COVID_DATA**

# %%
urlretrieve('https://gist.githubusercontent.com/aakashns/b2a968a6cfd9fbbb0ff3d6bd0f26262b/raw/b115ed1dfa17f10fc88bf966236cd4d9032f1df8/covid-countries-data.csv', 
            'covid-countries-data.csv')
# Out:
# ('covid-countries-data.csv', <http.client.HTTPMessage at 0x1eec091d1c0>)

# %%
covid_data_df = pd.read_csv('covid-countries-data.csv')

# %%
covid_data_df
# Out:
#            location  total_cases  total_deaths  total_tests
# 0       Afghanistan      38243.0        1409.0          NaN
# 1           Albania       9728.0         296.0          NaN
# 2           Algeria      45158.0        1525.0          NaN
# 3           Andorra       1199.0          53.0          NaN
# 4            Angola       2729.0         109.0          NaN
# ..              ...          ...           ...          ...
# 207  Western Sahara        766.0           1.0          NaN
# 208           World   26059065.0      863535.0          NaN
# 209           Yemen       1976.0         571.0          NaN
# 210          Zambia      12415.0         292.0          NaN
# 211        Zimbabwe       6638.0         206.0      97272.0
#
# [212 rows x 4 columns]

# %% [markdown]
# **Count the number of countries for which the `total_tests` data is missing.**

# %%
total_tests_missing = covid_data_df['total_tests'].isna().count()

# %%
print("The data for total tests is missing for {} countries.".format(int(total_tests_missing)))
# Out:
# The data for total tests is missing for 212 countries.

# %% [markdown]
# **Merge `countries_df` with `covid_data_df` on the `location` column.**

# %%
combined_df = countries_df.merge(covid_data_df,on='location')

# %%
combined_df
# Out:
#            location continent  population  life_expectancy  \
# 0       Afghanistan      Asia  38928341.0            64.83
# 1           Albania    Europe   2877800.0            78.57
# 2           Algeria    Africa  43851043.0            76.88
# 3           Andorra    Europe     77265.0            83.73
# 4            Angola    Africa  32866268.0            61.15
# ..              ...       ...         ...              ...
# 205         Vietnam      Asia  97338583.0            75.40
# 206  Western Sahara    Africa    597330.0            70.26
# 207           Yemen      Asia  29825968.0            66.12
# 208          Zambia    Africa  18383956.0            63.89
# 209        Zimbabwe    Africa  14862927.0            61.49
#
#      hospital_beds_per_thousand  gdp_per_capita           gdp  total_cases  \
# 0                          0.50        1803.987  7.022622e+10      38243.0
# 1                          2.89       11803.431  3.396791e+10       9728.0
# ...

# %% [markdown]
# **Add columns `tests_per_million`, `cases_per_million` and `deaths_per_million` into `combined_df`.**

# %%
combined_df['tests_per_million'] = combined_df['total_tests'] * 1e6 / combined_df['population']

# %%
combined_df['cases_per_million'] = combined_df['total_cases'] *1e6 / combined_df['population']

# %%
combined_df['deaths_per_million'] = combined_df['total_deaths'] * 1e6 / combined_df['population']

# %%
combined_df
# Out:
#            location continent  population  life_expectancy  \
# 0       Afghanistan      Asia  38928341.0            64.83
# 1           Albania    Europe   2877800.0            78.57
# 2           Algeria    Africa  43851043.0            76.88
# 3           Andorra    Europe     77265.0            83.73
# 4            Angola    Africa  32866268.0            61.15
# ..              ...       ...         ...              ...
# 205         Vietnam      Asia  97338583.0            75.40
# 206  Western Sahara    Africa    597330.0            70.26
# 207           Yemen      Asia  29825968.0            66.12
# 208          Zambia    Africa  18383956.0            63.89
# 209        Zimbabwe    Africa  14862927.0            61.49
#
#      hospital_beds_per_thousand  gdp_per_capita           gdp  total_cases  \
# 0                          0.50        1803.987  7.022622e+10      38243.0
# 1                          2.89       11803.431  3.396791e+10       9728.0
# ...

# %% [markdown]
# **Create a dataframe with 10 countires that have highest number of tests per million people.**

# %%
highest_tests_df = combined_df.sort_values('tests_per_million',ascending=False).head(10)

# %%
highest_tests_df
# Out:
#                  location      continent   population  life_expectancy  \
# 197  United Arab Emirates           Asia    9890400.0            77.97
# 14                Bahrain           Asia    1701583.0            77.29
# 115            Luxembourg         Europe     625976.0            82.25
# 122                 Malta         Europe     441539.0            82.53
# 53                Denmark         Europe    5792203.0            80.90
# 96                 Israel           Asia    8655541.0            82.97
# 89                Iceland         Europe     341250.0            82.99
# 157                Russia         Europe  145934460.0            72.58
# 199         United States  North America  331002647.0            78.86
# 10              Australia        Oceania   25499881.0            83.44
#
#      hospital_beds_per_thousand  gdp_per_capita           gdp  total_cases  \
# 197                       1.200       67293.483  6.655595e+11      71540.0
# ...

# %% [markdown]
# **Create a dataframe with 10 countires that have highest number of positive cases per million people.**

# %%
highest_cases_df = combined_df.sort_values('total_cases',ascending=False).head(10)

# %%
highest_cases_df
# Out:
#           location      continent    population  life_expectancy  \
# 199  United States  North America  3.310026e+08            78.86
# 27          Brazil  South America  2.125594e+08            75.88
# 90           India           Asia  1.380004e+09            69.66
# 157         Russia         Europe  1.459345e+08            72.58
# 150           Peru  South America  3.297185e+07            76.74
# 42        Colombia  South America  5.088288e+07            77.29
# 174   South Africa         Africa  5.930869e+07            64.13
# 125         Mexico  North America  1.289328e+08            75.05
# 177          Spain         Europe  4.675478e+07            83.56
# 7        Argentina  South America  4.519578e+07            76.67
#
#      hospital_beds_per_thousand  gdp_per_capita           gdp  total_cases  \
# 199                        2.77       54225.446  1.794877e+13    6114406.0
# 27                         2.20       14103.452  2.997821e+12    3997865.0
# ...

# %% [markdown]
# **Create a dataframe with 10 countires that have highest number of deaths cases per million people?**

# %%
highest_deaths_df = combined_df.sort_values('deaths_per_million',ascending=False).head(10)

# %%
highest_deaths_df
# Out:
#            location      continent   population  life_expectancy  \
# 162      San Marino         Europe      33938.0            84.97
# 150            Peru  South America   32971846.0            76.74
# 18          Belgium         Europe   11589616.0            81.63
# 3           Andorra         Europe      77265.0            83.73
# 177           Spain         Europe   46754783.0            83.56
# 198  United Kingdom         Europe   67886004.0            81.32
# 40            Chile  South America   19116209.0            80.18
# 97            Italy         Europe   60461828.0            83.51
# 27           Brazil  South America  212559409.0            75.88
# 182          Sweden         Europe   10099270.0            82.80
#
#      hospital_beds_per_thousand  gdp_per_capita           gdp  total_cases  \
# 162                        3.80       56861.470  1.929765e+09        735.0
# 150                        1.60       12236.706  4.034668e+11     663437.0
# ...

# %% [markdown]
# **Count number of countries that feature in both the lists of "highest number of tests per million" and "highest number of cases per million".**

# %%
import numpy as np
highest_number_of_tests_per_million = combined_df.sort_values('tests_per_million',ascending=False).head(10)['location']
highest_number_of_cases_per_million = combined_df.sort_values('cases_per_million',ascending=False).head(10)['location']



both  = pd.Series(np.intersect1d(highest_number_of_cases_per_million, highest_number_of_tests_per_million)).count()
both
# Out:
# 2

# %% [markdown]
# **Count number of countries that feature in both the lists "20 countries with lowest GDP per capita" and "20 countries with the lowest number of hospital beds per thousand population". Only consider countries with a population higher than 10 million while creating the list.**

# %%
countries20_with_low_gdp_per_capita = combined_df.sort_values('gdp_per_capita',ascending=True).head(20)

population_greater_than_10m_for_per_capita = countries20_with_low_gdp_per_capita['population'] > 10000000

c_1 = countries20_with_low_gdp_per_capita[population_greater_than_10m_for_per_capita]['location']

c_1
# Out:
# 32                          Burundi
# 52     Democratic Republic of Congo
# 140                           Niger
# 118                          Malawi
# 132                      Mozambique
# 117                      Madagascar
# 207                           Yemen
# 176                     South Sudan
# 85                            Haiti
# 195                          Uganda
# 31                     Burkina Faso
# 63                         Ethiopia
# Name: location, dtype: object

# %%
countries20_hospital_beds_per_thousand = combined_df.sort_values('hospital_beds_per_thousand',ascending=True).head(20)
population_greater_tha_10m_for_beds = countries20_hospital_beds_per_thousand['population']>10000000

c_2 = countries20_hospital_beds_per_thousand[population_greater_tha_10m_for_beds]['location']
c_2
# Out:
# 121            Mali
# 117      Madagascar
# 82           Guinea
# 63         Ethiopia
# 135           Nepal
# 140           Niger
# 31     Burkina Faso
# 0       Afghanistan
# 195          Uganda
# 20            Benin
# 90            India
# 145        Pakistan
# 80        Guatemala
# 207           Yemen
# 85            Haiti
# 187        Tanzania
# 132      Mozambique
# Name: location, dtype: object

# %%
both = pd.Series(np.intersect1d(c_1,c_2)).count()
both
# Out:
# 8

# %% [markdown]
# # Italy Covid Data Set

# %%
italy_covid_url = 'https://gist.githubusercontent.com/aakashns/f6a004fa20c84fec53262f9a8bfee775/raw/f309558b1cf5103424cef58e2ecb8704dcd4d74c/italy-covid-daywise.csv'

urlretrieve(italy_covid_url, 'italy-covid-daywise.csv')
# Out:
# ('italy-covid-daywise.csv', <http.client.HTTPMessage at 0x1eec091d490>)

# %%
covid_df = pd.read_csv('italy-covid-daywise.csv')

# %%
covid_df
# Out:
#            date  new_cases  new_deaths  new_tests
# 0    2019-12-31        0.0         0.0        NaN
# 1    2020-01-01        0.0         0.0        NaN
# 2    2020-01-02        0.0         0.0        NaN
# 3    2020-01-03        0.0         0.0        NaN
# 4    2020-01-04        0.0         0.0        NaN
# ..          ...        ...         ...        ...
# 243  2020-08-30     1444.0         1.0    53541.0
# 244  2020-08-31     1365.0         4.0    42583.0
# 245  2020-09-01      996.0         6.0    54395.0
# 246  2020-09-02      975.0         8.0        NaN
# 247  2020-09-03     1326.0         6.0        NaN
#
# [248 rows x 4 columns]

# %%
covid_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 248 entries, 0 to 247
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        248 non-null    object
#  1   new_cases   248 non-null    float64
#  2   new_deaths  248 non-null    float64
#  3   new_tests   135 non-null    float64
# dtypes: float64(3), object(1)
# memory usage: 7.9+ KB

# %%
covid_df.describe()
# Out:
#          new_cases  new_deaths     new_tests
# count   248.000000  248.000000    135.000000
# mean   1094.818548  143.133065  31699.674074
# std    1554.508002  227.105538  11622.209757
# min    -148.000000  -31.000000   7841.000000
# 25%     123.000000    3.000000  25259.000000
# 50%     342.000000   17.000000  29545.000000
# 75%    1371.750000  175.250000  37711.000000
# max    6557.000000  971.000000  95273.000000

# %%
covid_df.columns
# Out:
# Index(['date', 'new_cases', 'new_deaths', 'new_tests'], dtype='object')

# %%
covid_df.shape
# Out:
# (248, 4)

# %%
# Pandas format is simliar to this
covid_data_dict = {
    'date':       ['2020-08-30', '2020-08-31', '2020-09-01', '2020-09-02', '2020-09-03'],
    'new_cases':  [1444, 1365, 996, 975, 1326],
    'new_deaths': [1, 4, 6, 8, 6],
    'new_tests': [53541, 42583, 54395, None, None]
}

# %%
# Pandas format is not similar to this
covid_data_list = [
    {'date': '2020-08-30', 'new_cases': 1444, 'new_deaths': 1, 'new_tests': 53541},
    {'date': '2020-08-31', 'new_cases': 1365, 'new_deaths': 4, 'new_tests': 42583},
    {'date': '2020-09-01', 'new_cases': 996, 'new_deaths': 6, 'new_tests': 54395},
    {'date': '2020-09-02', 'new_cases': 975, 'new_deaths': 8 },
    {'date': '2020-09-03', 'new_cases': 1326, 'new_deaths': 6},
]

# %%
covid_data_dict['new_cases']
# Out:
# [1444, 1365, 996, 975, 1326]

# %% [markdown]
# Pandas also provides the .at method to retrieve the element at a specific row & column directly.

# %%
covid_df.at[246, 'new_cases']
# Out:
# 975.0

# %% [markdown]
# ## Analyzing data from data frames
#
#
#
# **What are the total number of reported cases and deaths related to Covid-19 in Italy?**

# %%
total_cases = covid_df.new_cases.sum()
total_deaths = covid_df.new_deaths.sum()


print('The number of reported cases is {} and the number of reported deaths is {}.'.format(int(total_cases), int(total_deaths)))
# Out:
# The number of reported cases is 271515 and the number of reported deaths is 35497.

# %% [markdown]
# **What is the overall death rate (ratio of reported deaths to reported cases)?**

# %%
death_rate = covid_df.new_deaths.sum() / covid_df.new_cases.sum()

print("The overall reported death rate in Italy is {:.2f} %.".format(death_rate*100))
# Out:
# The overall reported death rate in Italy is 13.07 %.

# %% [markdown]
# **What is the overall number of tests conducted? A total of 935310 tests were conducted before daily test numbers were reported.**

# %%
initial_tests = 935310

total_tests = initial_tests + covid_df.new_tests.sum()

total_tests
# Out:
# 5214766.0

# %% [markdown]
# **What fraction of tests returned a positive result?**

# %%
positive_rate = total_cases / total_tests

# %%
print('{:.2f}% of tests in Italy led to a positive diagnosis.'.format(positive_rate*100))
# Out:
# 5.21% of tests in Italy led to a positive diagnosis.

# %% [markdown]
# ## Querying and sorting rows

# %%
high_new_cases = covid_df.new_cases > 1000

# %%
high_new_cases
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 243     True
# 244     True
# 245    False
# 246    False
# 247     True
# Name: new_cases, Length: 248, dtype: bool

# %%
covid_df[high_new_cases]
# Out:
#            date  new_cases  new_deaths  new_tests
# 68   2020-03-08     1247.0        36.0        NaN
# 69   2020-03-09     1492.0       133.0        NaN
# 70   2020-03-10     1797.0        98.0        NaN
# 72   2020-03-12     2313.0       196.0        NaN
# 73   2020-03-13     2651.0       189.0        NaN
# ..          ...        ...         ...        ...
# 241  2020-08-28     1409.0         5.0    65135.0
# 242  2020-08-29     1460.0         9.0    64294.0
# 243  2020-08-30     1444.0         1.0    53541.0
# 244  2020-08-31     1365.0         4.0    42583.0
# 247  2020-09-03     1326.0         6.0        NaN
#
# [72 rows x 4 columns]

# %%
high_cases_df = covid_df[covid_df.new_cases > 1000]

# %%
high_cases_df
# Out:
#            date  new_cases  new_deaths  new_tests
# 68   2020-03-08     1247.0        36.0        NaN
# 69   2020-03-09     1492.0       133.0        NaN
# 70   2020-03-10     1797.0        98.0        NaN
# 72   2020-03-12     2313.0       196.0        NaN
# 73   2020-03-13     2651.0       189.0        NaN
# ..          ...        ...         ...        ...
# 241  2020-08-28     1409.0         5.0    65135.0
# 242  2020-08-29     1460.0         9.0    64294.0
# 243  2020-08-30     1444.0         1.0    53541.0
# 244  2020-08-31     1365.0         4.0    42583.0
# 247  2020-09-03     1326.0         6.0        NaN
#
# [72 rows x 4 columns]

# %% [markdown]
# ## Working with dates

# %% [markdown]
# The data type of date is currently `object`, so Pandas does not know that this column is a date. We can convert it into a `datetime` column using the `pd.to_datetime` method.

# %%
covid_df['date'] = pd.to_datetime(covid_df.date)

# %%
covid_df['date']
# Out:
# 0     2019-12-31
# 1     2020-01-01
# 2     2020-01-02
# 3     2020-01-03
# 4     2020-01-04
#          ...
# 243   2020-08-30
# 244   2020-08-31
# 245   2020-09-01
# 246   2020-09-02
# 247   2020-09-03
# Name: date, Length: 248, dtype: datetime64[ns]

# %%
covid_df['year'] = pd.DatetimeIndex(covid_df.date).year
covid_df['month'] = pd.DatetimeIndex(covid_df.date).month
covid_df['day'] = pd.DatetimeIndex(covid_df.date).day
covid_df['weekday'] = pd.DatetimeIndex(covid_df.date).weekday

# %%
covid_df
# Out:
#           date  new_cases  new_deaths  new_tests  year  month  day  weekday
# 0   2019-12-31        0.0         0.0        NaN  2019     12   31        1
# 1   2020-01-01        0.0         0.0        NaN  2020      1    1        2
# 2   2020-01-02        0.0         0.0        NaN  2020      1    2        3
# 3   2020-01-03        0.0         0.0        NaN  2020      1    3        4
# 4   2020-01-04        0.0         0.0        NaN  2020      1    4        5
# ..         ...        ...         ...        ...   ...    ...  ...      ...
# 243 2020-08-30     1444.0         1.0    53541.0  2020      8   30        6
# 244 2020-08-31     1365.0         4.0    42583.0  2020      8   31        0
# 245 2020-09-01      996.0         6.0    54395.0  2020      9    1        1
# 246 2020-09-02      975.0         8.0        NaN  2020      9    2        2
# 247 2020-09-03     1326.0         6.0        NaN  2020      9    3        3
#
# [248 rows x 8 columns]

# %% [markdown]
# ## Grouping and aggregation

# %%
covid_month_df = covid_df.groupby('month')[['new_cases', 'new_deaths', 'new_tests']].sum()

# %%
covid_month_df
# Out:
#        new_cases  new_deaths  new_tests
# month
# 1            3.0         0.0        0.0
# 2          885.0        21.0        0.0
# 3       100851.0     11570.0        0.0
# 4       101852.0     16091.0   419591.0
# 5        29073.0      5658.0  1078720.0
# 6         7772.0      1404.0   830354.0
# 7         6722.0       388.0   797692.0
# 8        21060.0       345.0  1098704.0
# 9         3297.0        20.0    54395.0
# 12           0.0         0.0        0.0

# %% [markdown]
# ## Basic Plotting with Pandas

# %%
covid_df.new_cases.plot();

# %%
covid_df.set_index('date', inplace=True)

# %%
covid_df
# Out:
#             new_cases  new_deaths  new_tests  year  month  day  weekday
# date
# 2019-12-31        0.0         0.0        NaN  2019     12   31        1
# 2020-01-01        0.0         0.0        NaN  2020      1    1        2
# 2020-01-02        0.0         0.0        NaN  2020      1    2        3
# 2020-01-03        0.0         0.0        NaN  2020      1    3        4
# 2020-01-04        0.0         0.0        NaN  2020      1    4        5
# ...               ...         ...        ...   ...    ...  ...      ...
# 2020-08-30     1444.0         1.0    53541.0  2020      8   30        6
# 2020-08-31     1365.0         4.0    42583.0  2020      8   31        0
# 2020-09-01      996.0         6.0    54395.0  2020      9    1        1
# 2020-09-02      975.0         8.0        NaN  2020      9    2        2
# 2020-09-03     1326.0         6.0        NaN  2020      9    3        3
#
# [248 rows x 7 columns]

# %%
covid_df.new_cases.plot()
covid_df.new_deaths.plot();

# %%
covid_month_df.new_cases.plot(kind='bar');

# %%
covid_month_df.new_cases.plot(kind='bar');
